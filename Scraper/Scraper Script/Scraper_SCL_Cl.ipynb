# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urljoin

# Read the CSV file
#df = pd.read_csv("urls_for_Klasse.csv")

# Extract the URLs

#urls = df["Reconstructed URLs"][:2].tolist()
urls = ["https://www.eversports.de/scl/poda-studio"]
base_url = "https://www.eversports.de/e/class/"

sessions = []

for url in urls:
    # Send a GET request to the URL
    response = requests.get(url)

    soup = BeautifulSoup(response.content, 'html.parser')

    workshop_elements = soup.find_all('li', class_='calendar__slot-bookable')
    for workshop_element in workshop_elements:
        session_short_id = workshop_element.get('data-session-short-id')
        session_time = workshop_element.find('div', class_='session-time').text.strip()
        session_name = workshop_element.find('div', class_='session-name').text.strip()
        available_slots = workshop_element.find('div', class_='ellipsis').text.strip()
        
        try:
            trainer_element = workshop_element.find('div', class_='ellipsis')
            trainer = trainer_element.find_next('div', class_='ellipsis').text.strip() if trainer_element else "0"
        except AttributeError:
            trainer = "0"
        
        try:
            room_element = workshop_element.find('div', class_='ellipsis')
            room = room_element.find_next('div', class_='ellipsis').find_next('div', class_='ellipsis').text.strip() if room_element else "0"
        except AttributeError:
            room = "0"

        workshop_info = {
            'URL': urljoin(base_url, session_short_id),
            'Time': session_time.split(" ● ")[0],
            'Duration': session_time.split(" ● ")[1],
            'Name': session_name,
            'Available Slots': available_slots,
            'Trainer': trainer,
            'Room': room
        }
        sessions.append(workshop_info)

# Create a DataFrame
df = pd.DataFrame(sessions)

# Print the DataFrame
print(df)
# Out:
#                                               URL   Time Duration  \
# 0       https://www.eversports.de/e/class/ROgPMlw  08:00   60 Min
# 1       https://www.eversports.de/e/class/j6tDq5v  16:30   60 Min
# 2       https://www.eversports.de/e/class/AieL128  13:00   60 Min
# 3   https://www.eversports.de/e/class/0thHFXFibWF  14:00   60 Min
# 4       https://www.eversports.de/e/class/y8z51L7  15:15   60 Min
# 5       https://www.eversports.de/e/class/e_mdnES  16:30   60 Min
# 6       https://www.eversports.de/e/class/K9ftD1M  17:30   60 Min
# 7       https://www.eversports.de/e/class/u2amdE7  18:45   60 Min
# 8       https://www.eversports.de/e/class/mz9ObNJ  20:00   60 Min
# 9       https://www.eversports.de/e/class/S707Ec0  21:15   60 Min
# 10      https://www.eversports.de/e/class/i67sTtb  17:30   60 Min
# 11      https://www.eversports.de/e/class/rIZ6YAY  18:45   60 Min
# 12      https://www.eversports.de/e/class/XN-tiEF  20:00   60 Min
# 13      https://www.eversports.de/e/class/UnyMSd_  21:15   60 Min
# 14      https://www.eversports.de/e/class/EImzmAX  17:30   60 Min
# 15      https://www.eversports.de/e/class/hPLflP5  18:45   60 Min
# 16      https://www.eversports.de/e/class/zCdvQ7W  20:00   60 Min
# 17      https://www.eversports.de/e/class/EuObHhM  21:15   60 Min
# 18      https://www.eversports.de/e/class/gerQlwn  17:30   60 Min
# 19      https://www.eversports.de/e/class/lXiBfIN  18:45   60 Min
# 20      https://www.eversports.de/e/class/YiFC9x8  20:00   60 Min
# 21      https://www.eversports.de/e/class/jdpVSCv  20:00   60 Min
# 22      https://www.eversports.de/e/class/SDkp8x3  21:15   60 Min
# 23      https://www.eversports.de/e/class/63tU294  17:30   60 Min
# 24      https://www.eversports.de/e/class/qyfmuic  18:45   60 Min
# 25      https://www.eversports.de/e/class/qMTjqOU  17:45   60 Min
# 26      https://www.eversports.de/e/class/Auqhl-X  19:00   60 Min
# 27      https://www.eversports.de/e/class/j6tDq5v  16:30   60 Min
# 28      https://www.eversports.de/e/class/K9ftD1M  17:30   60 Min
# 29      https://www.eversports.de/e/class/u2amdE7  18:45   60 Min
# 30      https://www.eversports.de/e/class/mz9ObNJ  20:00   60 Min
# 31      https://www.eversports.de/e/class/S707Ec0  21:15   60 Min
# 32      https://www.eversports.de/e/class/i67sTtb  17:30   60 Min
# 33      https://www.eversports.de/e/class/rIZ6YAY  18:45   60 Min
# 34      https://www.eversports.de/e/class/XN-tiEF  20:00   60 Min
# 35      https://www.eversports.de/e/class/UnyMSd_  21:15   60 Min
# 36      https://www.eversports.de/e/class/ROgPMlw  08:00   60 Min
# 37      https://www.eversports.de/e/class/EImzmAX  17:30   60 Min
# 38      https://www.eversports.de/e/class/hPLflP5  18:45   60 Min
# 39      https://www.eversports.de/e/class/zCdvQ7W  20:00   60 Min
# 40      https://www.eversports.de/e/class/EuObHhM  21:15   60 Min
# 41      https://www.eversports.de/e/class/gerQlwn  17:30   60 Min
# 42      https://www.eversports.de/e/class/lXiBfIN  18:45   60 Min
# 43      https://www.eversports.de/e/class/YiFC9x8  20:00   60 Min
# 44      https://www.eversports.de/e/class/jdpVSCv  20:00   60 Min
# 45      https://www.eversports.de/e/class/SDkp8x3  21:15   60 Min
# 46      https://www.eversports.de/e/class/63tU294  17:30   60 Min
# 47      https://www.eversports.de/e/class/qyfmuic  18:45   60 Min
# 48      https://www.eversports.de/e/class/AieL128  13:00   60 Min
# 49  https://www.eversports.de/e/class/0thHFXFibWF  14:00   60 Min
# 50      https://www.eversports.de/e/class/y8z51L7  15:15   60 Min
# 51      https://www.eversports.de/e/class/e_mdnES  16:30   60 Min
# 52      https://www.eversports.de/e/class/qMTjqOU  17:45   60 Min
# 53      https://www.eversports.de/e/class/Auqhl-X  19:00   60 Min
#
#                                       Name          Available Slots  \
# 0                              Aerial Yoga               ausgebucht
# 1                        Pole & Aerial Jam  14/24 Plätzen verfügbar
# 2                        Pole & Aerial Jam  16/24 Plätzen verfügbar
# 3   Pole Dance Probestunde | Try out class   4/12 Plätzen verfügbar
# 4                 Pole Dance Beginner + L1               ausgebucht
# 5                              Flexibility                 Abgesagt
# 6                      Pole Dance Beginner   5/12 Plätzen verfügbar
# 7                       Pole Dance Level 4   5/12 Plätzen verfügbar
# 8                       Pole Dance Level 3   6/12 Plätzen verfügbar
# 9                       Pole Dance Level 3                 Abgesagt
# 10                      Pole Dance Level 1   5/12 Plätzen verfügbar
# 11                   Pole Tricks Level 2+3   5/12 Plätzen verfügbar
# 12               Luftakrobatik Aerial Hoop   7/16 Plätzen verfügbar
# 13                             Chair Dance  17/24 Plätzen verfügbar
# 14                      Pole Dance Level 3   8/12 Plätzen verfügbar
# 15                            Pole Fitness  13/24 Plätzen verfügbar
# 16                      Pole Dance Level 2   6/12 Plätzen verfügbar
# 17    High Heels- Exotic Pole Intermediate   5/12 Plätzen verfügbar
# 18                   Pole Tricks Level 3+4   7/12 Plätzen verfügbar
# 19                     Pole Dance Beginner   4/12 Plätzen verfügbar
# 20                      Pole Dance Level 1                 Abgesagt
# 21                       Pole & Aerial Jam  18/24 Plätzen verfügbar
# 22                      Pole Dance Level 2   6/12 Plätzen verfügbar
# 23                   Pole Tricks Level 1+2   5/12 Plätzen verfügbar
# 24                       Contemporary Pole   6/12 Plätzen verfügbar
# 25                   Pole Tricks Level 2+3               ausgebucht
# 26   High Heels - Exotic Pole Beg./Interm.   6/12 Plätzen verfügbar
# 27                       Pole & Aerial Jam  14/24 Plätzen verfügbar
# 28                     Pole Dance Beginner   5/12 Plätzen verfügbar
# 29                      Pole Dance Level 4   5/12 Plätzen verfügbar
# 30                      Pole Dance Level 3   6/12 Plätzen verfügbar
# 31                      Pole Dance Level 3                 Abgesagt
# 32                      Pole Dance Level 1   5/12 Plätzen verfügbar
# 33                   Pole Tricks Level 2+3   5/12 Plätzen verfügbar
# 34               Luftakrobatik Aerial Hoop   7/16 Plätzen verfügbar
# 35                             Chair Dance  17/24 Plätzen verfügbar
# 36                             Aerial Yoga               ausgebucht
# 37                      Pole Dance Level 3   8/12 Plätzen verfügbar
# 38                            Pole Fitness  13/24 Plätzen verfügbar
# 39                      Pole Dance Level 2   6/12 Plätzen verfügbar
# 40    High Heels- Exotic Pole Intermediate   5/12 Plätzen verfügbar
# 41                   Pole Tricks Level 3+4   7/12 Plätzen verfügbar
# 42                     Pole Dance Beginner   4/12 Plätzen verfügbar
# 43                      Pole Dance Level 1                 Abgesagt
# 44                       Pole & Aerial Jam  18/24 Plätzen verfügbar
# 45                      Pole Dance Level 2   6/12 Plätzen verfügbar
# 46                   Pole Tricks Level 1+2   5/12 Plätzen verfügbar
# 47                       Contemporary Pole   6/12 Plätzen verfügbar
# 48                       Pole & Aerial Jam  16/24 Plätzen verfügbar
# 49  Pole Dance Probestunde | Try out class   4/12 Plätzen verfügbar
# 50                Pole Dance Beginner + L1               ausgebucht
# 51                             Flexibility                 Abgesagt
# 52                   Pole Tricks Level 2+3               ausgebucht
# 53   High Heels - Exotic Pole Beg./Interm.   6/12 Plätzen verfügbar
#
#                     Trainer                    Room
# 0                      Emmy             Poda Studio
# 1                      o.T.             Poda Studio
# 2                      o.T.             Poda Studio
# 3                     Diana             Poda Studio
# 4                     Diana             Poda Studio
# 5    5/12 Plätzen verfügbar                   Diana
# 6                     Diana             Poda Studio
# 7                      Anna             Poda Studio
# 8                      Anna             Poda Studio
# 9    5/12 Plätzen verfügbar                    Emmy
# 10                     Emmy             Poda Studio
# 11                     Emmy             Poda Studio
# 12                     Emmy             Poda Studio
# 13                     Emmy             Poda Studio
# 14                     Anna             Poda Studio
# 15                     Anna             Poda Studio
# 16                     Anna             Poda Studio
# 17                   Celine             Poda Studio
# 18                   Celine             Poda Studio
# 19                   Celine             Poda Studio
# 20  18/24 Plätzen verfügbar             Poda Studio
# 21              Poda Studio  6/12 Plätzen verfügbar
# 22                   Celine             Poda Studio
# 23                    Diana             Poda Studio
# 24                    Diana             Poda Studio
# 25                   Celine             Poda Studio
# 26                   Celine             Poda Studio
# 27                     o.T.             Poda Studio
# 28                    Diana             Poda Studio
# 29                     Anna             Poda Studio
# 30                     Anna             Poda Studio
# 31   5/12 Plätzen verfügbar                    Emmy
# 32                     Emmy             Poda Studio
# 33                     Emmy             Poda Studio
# 34                     Emmy             Poda Studio
# 35                     Emmy             Poda Studio
# 36                     Emmy             Poda Studio
# 37                     Anna             Poda Studio
# 38                     Anna             Poda Studio
# 39                     Anna             Poda Studio
# 40                   Celine             Poda Studio
# 41                   Celine             Poda Studio
# 42                   Celine             Poda Studio
# 43  18/24 Plätzen verfügbar             Poda Studio
# 44              Poda Studio  6/12 Plätzen verfügbar
# 45                   Celine             Poda Studio
# 46                    Diana             Poda Studio
# 47                    Diana             Poda Studio
# 48                     o.T.             Poda Studio
# 49                    Diana             Poda Studio
# 50                    Diana             Poda Studio
# 51               ausgebucht                  Celine
# 52                   Celine             Poda Studio
# 53                   Celine             Poda Studio

# %%
len(df["URL"].unique())
# Out:
# 1881

# %%
df
# Out:
#                                                URL   Time Duration  \
# 0     https://www.eversports.de/e/class/5izpH6DTkJ  11:15   60 Min
# 1     https://www.eversports.de/e/class/5A4nfSHWg-  11:15   75 Min
# 2     https://www.eversports.de/e/class/f-0r0ToSgK  15:30   75 Min
# 3     https://www.eversports.de/e/class/aKboL3DKUQ  15:45   60 Min
# 4     https://www.eversports.de/e/class/mGkzoEiBQS  15:30   75 Min
# ...                                            ...    ...      ...
# 5533  https://www.eversports.de/e/class/HsCca4-MDD  14:00   60 Min
# 5534  https://www.eversports.de/e/class/YjKr1tlxs6  15:15   60 Min
# 5535  https://www.eversports.de/e/class/vxu9nqPcVa  16:30   60 Min
# 5536  https://www.eversports.de/e/class/hXWrVTc2i9  17:45   60 Min
# 5537  https://www.eversports.de/e/class/ugBYKc-sP0  19:00   60 Min
#
#                                        Name              Available Slots  \
# 0                           Freies Training     Alle Level4 freie Plätze
# 1                     Pole Mix - all levels         Alle Levelausgebucht
# 2             Pole STARTER/ Schnupperstunde       Anfänger1 freier Platz
# 3                               Twerk Class  Alle Levelmehr als 5 Plätze
# 4                                     Basic       Anfänger1 freier Platz
# ...                                     ...                          ...
# 5533                 Pole Dance Probestunde      12/12 Plätzen verfügbar
# 5534               Pole Dance Beginner + L1      11/12 Plätzen verfügbar
# 5535                            Flexibility      19/24 Plätzen verfügbar
# 5536                  Pole Tricks Level 2+3       3/12 Plätzen verfügbar
# 5537  High Heels - Exotic Pole Beg./Interm.       4/12 Plätzen verfügbar
#
#                        Trainer                      Room
# 0     Raum grau_Friesenstrasse      Alle Levelausgebucht
# 1                        Tabea  Raum rosa_Friesenstrasse
# 2                      Leonora  Raum grau_Friesenstrasse
# 3                    Shardelle       Aerial Goethestraße
# 4                    Shardelle  Raum rosa_Friesenstrasse
# ...                        ...                       ...
# 5533                     Diana               Poda Studio
# 5534                      Lena               Poda Studio
# 5535                      Lena               Poda Studio
# 5536                      Lena               Poda Studio
# 5537                    Celine               Poda Studio
#
# [5538 rows x 7 columns]

# %%
unique_rows = df[~df["URL"].duplicated()].reset_index(drop=True)
print(unique_rows)
# Out:
#                                                URL   Time Duration  \
# 0     https://www.eversports.de/e/class/5izpH6DTkJ  11:15   60 Min
# 1     https://www.eversports.de/e/class/5A4nfSHWg-  11:15   75 Min
# 2     https://www.eversports.de/e/class/f-0r0ToSgK  15:30   75 Min
# 3     https://www.eversports.de/e/class/aKboL3DKUQ  15:45   60 Min
# 4     https://www.eversports.de/e/class/mGkzoEiBQS  15:30   75 Min
# ...                                            ...    ...      ...
# 1876  https://www.eversports.de/e/class/5aejkG2MED  18:45   60 Min
# 1877  https://www.eversports.de/e/class/rBA54O-3lY  20:00   60 Min
# 1878  https://www.eversports.de/e/class/TNFYSb9HW8  21:00   60 Min
# 1879  https://www.eversports.de/e/class/hXWrVTc2i9  17:45   60 Min
# 1880  https://www.eversports.de/e/class/ugBYKc-sP0  19:00   60 Min
#
#                                        Name              Available Slots  \
# 0                           Freies Training     Alle Level4 freie Plätze
# 1                     Pole Mix - all levels         Alle Levelausgebucht
# 2             Pole STARTER/ Schnupperstunde       Anfänger1 freier Platz
# 3                               Twerk Class  Alle Levelmehr als 5 Plätze
# 4                                     Basic       Anfänger1 freier Platz
# ...                                     ...                          ...
# 1876                     Pole Dance Level 3       5/12 Plätzen verfügbar
# 1877      High Heels - Exotic Pole Beginner       4/12 Plätzen verfügbar
# 1878                               Pole Jam      18/24 Plätzen verfügbar
# 1879                  Pole Tricks Level 2+3       3/12 Plätzen verfügbar
# 1880  High Heels - Exotic Pole Beg./Interm.       4/12 Plätzen verfügbar
#
#                        Trainer                      Room
# 0     Raum grau_Friesenstrasse      Alle Levelausgebucht
# 1                        Tabea  Raum rosa_Friesenstrasse
# 2                      Leonora  Raum grau_Friesenstrasse
# 3                    Shardelle       Aerial Goethestraße
# 4                    Shardelle  Raum rosa_Friesenstrasse
# ...                        ...                       ...
# 1876                      Lena               Poda Studio
# 1877                     Diana               Poda Studio
# 1878               Poda Studio    3/12 Plätzen verfügbar
# 1879                      Lena               Poda Studio
# 1880                    Celine               Poda Studio
#
# [1881 rows x 7 columns]

# %%
unique_rows
# Out:
#                                                URL   Time Duration  \
# 0     https://www.eversports.de/e/class/5izpH6DTkJ  11:15   60 Min
# 1     https://www.eversports.de/e/class/5A4nfSHWg-  11:15   75 Min
# 2     https://www.eversports.de/e/class/f-0r0ToSgK  15:30   75 Min
# 3     https://www.eversports.de/e/class/aKboL3DKUQ  15:45   60 Min
# 4     https://www.eversports.de/e/class/mGkzoEiBQS  15:30   75 Min
# ...                                            ...    ...      ...
# 1876  https://www.eversports.de/e/class/5aejkG2MED  18:45   60 Min
# 1877  https://www.eversports.de/e/class/rBA54O-3lY  20:00   60 Min
# 1878  https://www.eversports.de/e/class/TNFYSb9HW8  21:00   60 Min
# 1879  https://www.eversports.de/e/class/hXWrVTc2i9  17:45   60 Min
# 1880  https://www.eversports.de/e/class/ugBYKc-sP0  19:00   60 Min
#
#                                        Name              Available Slots  \
# 0                           Freies Training     Alle Level4 freie Plätze
# 1                     Pole Mix - all levels         Alle Levelausgebucht
# 2             Pole STARTER/ Schnupperstunde       Anfänger1 freier Platz
# 3                               Twerk Class  Alle Levelmehr als 5 Plätze
# 4                                     Basic       Anfänger1 freier Platz
# ...                                     ...                          ...
# 1876                     Pole Dance Level 3       5/12 Plätzen verfügbar
# 1877      High Heels - Exotic Pole Beginner       4/12 Plätzen verfügbar
# 1878                               Pole Jam      18/24 Plätzen verfügbar
# 1879                  Pole Tricks Level 2+3       3/12 Plätzen verfügbar
# 1880  High Heels - Exotic Pole Beg./Interm.       4/12 Plätzen verfügbar
#
#                        Trainer                      Room
# 0     Raum grau_Friesenstrasse      Alle Levelausgebucht
# 1                        Tabea  Raum rosa_Friesenstrasse
# 2                      Leonora  Raum grau_Friesenstrasse
# 3                    Shardelle       Aerial Goethestraße
# 4                    Shardelle  Raum rosa_Friesenstrasse
# ...                        ...                       ...
# 1876                      Lena               Poda Studio
# 1877                     Diana               Poda Studio
# 1878               Poda Studio    3/12 Plätzen verfügbar
# 1879                      Lena               Poda Studio
# 1880                    Celine               Poda Studio
#
# [1881 rows x 7 columns]

# %%
unique_rows.to_csv("URLS_SCL_Workshops.csv")
